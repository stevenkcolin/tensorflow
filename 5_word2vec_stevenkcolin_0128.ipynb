# %% [markdown]
# <a href="https://colab.research.google.com/github/stevenkcolin/tensorflow/blob/master/5_word2vec_stevenkcolin_0128.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# 练习题在python2 + gpu colab环境下调试通过
# !ls -lt
# Out:
# total 30616
# -rw-r--r-- 1 root root 31344016 Jan 29 10:20 text8.zip
# drwxr-xr-x 1 root root     4096 Jan  8 17:15 sample_data

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'originated', 'anarchism', 'originated', 'as', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.714612
# Nearest to other: kj, prosecute, doublespeak, him, compressed, sidecar, devotes, mineral,
# Nearest to that: minyan, regulatory, saltpeter, loophole, kames, consecrations, subdued, lovejoy,
# Nearest to system: connie, stuck, argentina, swearing, hyperfine, singularities, titanium, materiel,
# Nearest to when: nightclub, disparate, heyday, nik, dnow, townspeople, stones, inexorably,
# Nearest to was: fertility, biochemist, incorporating, brotherhoods, hank, ceasing, isolating, barrister,
# Nearest to there: lingua, viola, birthright, duplication, irritated, fray, chiba, bursting,
# Nearest to state: bondi, gheg, habitability, corn, amerindian, theorized, hurried, quotes,
# Nearest to were: insanity, cherokee, anjiro, luncheon, multithreading, rationalized, fanfic, irina,
# Nearest to new: multiparty, workman, abijah, heterosexuals, summaries, slightest, creighton, informatique,
# Nearest to these: dispersion, rockstar, pairs, graphene, lodged, simpson, shift, reproductive,
# Nearest to such: turning, disciplined, rows, ravi, mummification, slaughtering, rhythm, coiled,
# Nearest to all: circumventing, wimp, fet, remixed, tomb, markkaa, whiz, homeschool,
# Nearest to often: dearly, crimson, yaoi, threshold, albedo, pca, exclamation, abbots,
# Nearest to called: zur, sinbad, dien, edgerton, brooms, infinities, volumes, torment,
# Nearest to with: cpr, actinide, tries, educator, oda, greetings, ogle, vella,
# Nearest to UNK: renamed, hexer, practiced, mayor, transnational, erm, adventist, corner,
# Average loss at step 2000: 4.374416
# Average loss at step 4000: 3.865979
# Average loss at step 6000: 3.792302
# Average loss at step 8000: 3.685265
# Average loss at step 10000: 3.608524
# Nearest to other: kj, escorial, killed, menagerie, leicestershire, theorist, kobayashi, stagecoach,
# Nearest to that: which, midline, bopp, it, saltpeter, minyan, ambivalence, kames,
# Nearest to system: devito, journals, connie, stuck, swearing, investiture, synthesize, decimals,
# Nearest to when: disparate, reagent, heyday, decision, mvs, catherine, ichi, licklider,
# Nearest to was: is, has, had, were, by, are, whilst, been,
# Nearest to there: it, he, birthright, viola, fray, they, lingua, campion,
# Nearest to state: organs, transcribe, uk, avesta, bondi, diplomacy, absurdity, amerindian,
# Nearest to were: are, insanity, was, have, lagos, anjiro, bodyguard, brundtland,
# Nearest to new: yacht, curator, initiating, abijah, tsim, informatique, df, flaming,
# Nearest to these: dispersion, rockstar, hinge, ellen, burnt, islamists, many, incorporates,
# Nearest to such: republika, well, turning, rhythm, imbalance, cerrado, rows, disciplined,
# Nearest to all: fifteenth, ion, machado, part, overarching, geopolitics, golfo, steady,
# Nearest to often: dearly, not, also, yaoi, zr, simultaneity, she, gaze,
# Nearest to called: boccaccio, edgerton, decree, zur, sadc, bedtime, matejko, sargon,
# Nearest to with: on, matti, for, from, in, greetings, consensual, or,
# Nearest to UNK: al, gustav, generous, majorana, livelihoods, educational, wrexham, newline,
# Average loss at step 12000: 3.608803
# Average loss at step 14000: 3.573127
# Average loss at step 16000: 3.411850
# Average loss at step 18000: 3.456040
# Average loss at step 20000: 3.540152
# Nearest to other: many, kj, these, various, escorial, some, menagerie, different,
# Nearest to that: which, but, midline, this, saltpeter, auteur, rouen, know,
# Nearest to system: titanium, devito, synthesize, stuck, journals, connie, swearing, celtics,
# Nearest to when: after, where, disparate, is, though, won, because, was,
# Nearest to was: is, has, had, were, be, became, been, by,
# Nearest to there: they, it, which, he, birthright, viola, piercing, still,
# Nearest to state: uk, bondi, organs, avesta, transcribe, diplomacy, amerindian, country,
# Nearest to were: are, was, had, have, herr, is, though, grosse,
# Nearest to new: df, initiating, greyhounds, rising, curator, expires, yacht, multiparty,
# Nearest to these: many, some, such, other, all, which, hinge, dispersion,
# Nearest to such: well, these, republika, known, disciplined, rhythm, cerrado, turning,
# Nearest to all: these, many, fifteenth, corticosteroids, ion, some, elmer, overarching,
# Nearest to often: also, generally, not, sometimes, subsequently, falwell, there, dearly,
# Nearest to called: subtitling, boccaccio, alte, decree, asiatic, sadc, known, rukh,
# Nearest to with: greetings, in, by, matti, between, for, budd, educator,
# Nearest to UNK: maois, laureate, doyle, sexist, piss, bandage, amiga, electrophoresis,
# Average loss at step 22000: 3.506290
# Average loss at step 24000: 3.488980
# Average loss at step 26000: 3.484981
# Average loss at step 28000: 3.481183
# Average loss at step 30000: 3.503285
# Nearest to other: kj, various, many, these, different, escorial, some, menagerie,
# Nearest to that: which, what, this, but, notary, midline, piercing, auteur,
# Nearest to system: systems, titanium, investiture, journals, decimals, sims, format, swearing,
# Nearest to when: after, but, where, because, though, until, before, if,
# Nearest to was: is, had, were, has, became, been, be, sines,
# Nearest to there: they, it, he, piercing, still, this, which, often,
# Nearest to state: organs, country, bondi, coping, eschatological, uk, transcribe, diplomacy,
# Nearest to were: are, was, had, have, been, grosse, be, is,
# Nearest to new: surrounding, df, jamestown, greyhounds, initiating, famines, rstenberg, curator,
# Nearest to these: many, some, such, several, they, all, other, which,
# Nearest to such: well, these, known, some, republika, many, pestis, disciplined,
# Nearest to all: some, delineated, fifteenth, these, many, both, golfo, vorder,
# Nearest to often: sometimes, generally, also, usually, commonly, there, subsequently, still,
# Nearest to called: used, calicut, subtitling, rukh, asiatic, milford, cromwell, alte,
# Nearest to with: between, against, in, during, for, giving, among, matti,
# Nearest to UNK: urged, refitted, iadb, razed, chemicals, chiles, keynote, lincoln,
# Average loss at step 32000: 3.497055
# Average loss at step 34000: 3.493809
# Average loss at step 36000: 3.454363
# Average loss at step 38000: 3.301662
# Average loss at step 40000: 3.425945
# Nearest to other: various, kj, different, escorial, many, nilpotent, more, deviant,
# Nearest to that: which, this, what, however, auteur, where, reprise, dent,
# Nearest to system: systems, investiture, format, stuck, titanium, phytoplankton, journals, weights,
# Nearest to when: before, if, where, after, but, while, because, until,
# Nearest to was: is, were, became, had, been, be, has, sines,
# Nearest to there: it, they, he, which, she, still, vineyard, these,
# Nearest to state: country, heinkel, eschatological, government, organs, uk, coping, romanians,
# Nearest to were: are, have, was, had, while, been, these, be,
# Nearest to new: rstenberg, surrounding, yacht, fibre, initiating, hendrick, jamestown, modern,
# Nearest to these: many, some, such, several, are, different, they, which,
# Nearest to such: well, these, known, republika, some, including, many, enos,
# Nearest to all: these, both, sanj, any, moluccas, out, delineated, fifteenth,
# Nearest to often: usually, generally, also, sometimes, commonly, which, now, still,
# Nearest to called: named, used, cromwell, known, calicut, milford, wa, rukh,
# Nearest to with: against, between, greetings, in, when, by, ignorant, matti,
# Nearest to UNK: von, b, gehenna, d, molloy, bskyb, chocolate, thales,
# Average loss at step 42000: 3.433975
# Average loss at step 44000: 3.452345
# Average loss at step 46000: 3.448421
# Average loss at step 48000: 3.356419
# Average loss at step 50000: 3.386427
# Nearest to other: various, different, escorial, many, kj, some, others, nilpotent,
# Nearest to that: which, however, what, microorganisms, but, orkney, stallion, sinan,
# Nearest to system: systems, format, stuck, investiture, titanium, electrified, phytoplankton, journals,
# Nearest to when: after, before, while, if, where, but, until, during,
# Nearest to was: is, were, has, had, been, by, became, be,
# Nearest to there: it, they, he, she, still, often, which, who,
# Nearest to state: romanians, bondi, organs, eschatological, city, ornithologists, classification, explain,
# Nearest to were: are, was, have, had, although, been, be, myron,
# Nearest to new: surrounding, single, navigating, mess, specific, characterises, yacht, fibre,
# Nearest to these: many, some, several, such, both, various, which, are,
# Nearest to such: well, these, known, republika, many, pestis, regarded, caricatures,
# Nearest to all: both, elmer, some, those, various, moluccas, many, these,
# Nearest to often: generally, sometimes, usually, commonly, also, now, which, widely,
# Nearest to called: known, milford, alleviate, powering, named, used, colophon, calicut,
# Nearest to with: between, by, matti, greetings, against, tributary, when, giving,
# Nearest to UNK: et, cours, la, gout, thales, smuggled, macmanus, kassel,
# Average loss at step 52000: 3.433113
# Average loss at step 54000: 3.427848
# Average loss at step 56000: 3.440105
# Average loss at step 58000: 3.393401
# Average loss at step 60000: 3.393587
# Nearest to other: different, various, escorial, kj, many, others, including, several,
# Nearest to that: which, however, this, preterist, what, but, sinan, it,
# Nearest to system: systems, format, titanium, policy, investiture, surveyors, journals, persecutions,
# Nearest to when: if, after, although, before, while, where, during, though,
# Nearest to was: is, became, had, were, has, be, been, becomes,
# Nearest to there: they, it, he, she, still, often, now, this,
# Nearest to state: city, eschatological, government, territory, ornithologists, country, violation, explain,
# Nearest to were: are, was, had, have, although, been, including, while,
# Nearest to new: jamestown, df, rstenberg, mess, famines, fibre, greyhounds, specific,
# Nearest to these: many, some, several, such, both, those, which, various,
# Nearest to such: well, these, known, republika, including, bentham, enos, many,
# Nearest to all: those, both, many, some, various, any, delineated, elmer,
# Nearest to often: sometimes, usually, generally, now, commonly, also, still, frequently,
# Nearest to called: used, known, named, alleviate, colophon, referred, powering, milford,
# Nearest to with: between, greetings, matti, when, including, among, ignorant, swan,
# Nearest to UNK: grapes, neoliberalism, coronado, bluntly, pear, chop, reprimanded, atomists,
# Average loss at step 62000: 3.241955
# Average loss at step 64000: 3.251919
# Average loss at step 66000: 3.403081
# Average loss at step 70000: 3.358861
# Nearest to other: various, different, escorial, others, many, kj, including, defensive,
# Nearest to that: which, however, what, this, often, but, preterist, where,
# Nearest to system: systems, format, policy, titanium, journals, stuck, investiture, gustaf,
# Nearest to when: if, while, where, because, before, after, although, though,
# Nearest to was: is, were, has, had, became, been, be, when,
# Nearest to there: they, it, often, he, still, generally, we, this,
# Nearest to state: city, states, territory, ornithologists, government, valery, secretory, uk,
# Nearest to were: are, was, have, had, been, be, although, jasmuheen,
# Nearest to new: jamestown, specific, fibre, mess, df, certain, famines, hendrick,
# Nearest to these: some, such, many, several, various, their, those, are,
# Nearest to such: well, these, known, many, republika, regarded, bentham, safeguarded,
# Nearest to all: some, various, many, those, any, every, both, destry,
# Nearest to often: sometimes, usually, generally, now, commonly, frequently, still, there,
# Nearest to called: used, named, referred, known, colophon, levitation, see, shed,
# Nearest to with: between, swan, greetings, pear, against, bodied, by, ogle,
# Nearest to UNK: cours, caps, chemicals, gaussian, incompetent, hesse, eschewing, codepages,
# Average loss at step 72000: 3.373112
# Average loss at step 74000: 3.347449
# Average loss at step 76000: 3.314296
# Average loss at step 78000: 3.352203
# Average loss at step 80000: 3.381435
# Nearest to other: various, others, escorial, many, defensive, endeavoured, different, kj,
# Nearest to that: however, which, preterist, where, orkney, what, regarding, sinan,
# Nearest to system: systems, format, stuck, journals, policy, phytoplankton, program, pernoud,
# Nearest to when: before, if, after, although, while, though, where, during,
# Nearest to was: is, became, had, were, has, been, although, brundtland,
# Nearest to there: it, they, he, often, now, she, generally, still,
# Nearest to state: city, uk, territory, states, government, maududi, ornithologists, heinkel,
# Nearest to were: are, was, had, have, been, although, reticulum, brest,
# Nearest to new: jamestown, conics, famines, specific, rising, recording, fibre, mess,
# Nearest to these: several, many, various, such, those, some, both, different,
# Nearest to such: well, these, known, certain, various, republika, enos, including,
# Nearest to all: both, various, many, every, some, any, each, those,
# Nearest to often: sometimes, usually, generally, commonly, now, frequently, typically, still,
# Nearest to called: referred, named, used, known, considered, syncopation, alte, colophon,
# Nearest to with: between, against, antipope, when, greetings, ogle, including, if,
# Nearest to UNK: williams, forecasting, j, abdul, et, singer, eubank, alexius,
# Average loss at step 82000: 3.407901
# Average loss at step 84000: 3.410188
# Average loss at step 86000: 3.391000
# Average loss at step 88000: 3.350399
# Average loss at step 90000: 3.365397
# Nearest to other: various, escorial, different, defensive, including, others, kj, furthest,
# Nearest to that: which, however, what, minyan, but, reprise, accompanying, then,
# Nearest to system: systems, slice, cordial, policy, program, stuck, journals, nederlandse,
# Nearest to when: before, if, although, while, after, where, though, because,
# Nearest to was: is, had, became, were, has, been, be, inductor,
# Nearest to there: it, they, he, generally, now, she, still, often,
# Nearest to state: city, states, territory, government, uk, ornithologists, browed, juridical,
# Nearest to were: are, had, was, have, although, while, been, those,
# Nearest to new: jamestown, northern, specific, famines, conics, greyhounds, terminals, df,
# Nearest to these: several, many, some, various, those, are, certain, such,
# Nearest to such: well, known, these, certain, follows, enos, cerrado, republika,
# Nearest to all: many, both, some, various, every, several, those, elmer,
# Nearest to often: usually, sometimes, generally, commonly, now, frequently, typically, still,
# Nearest to called: named, known, referred, used, considered, valera, attributed, lawn,
# Nearest to with: between, in, against, conquering, by, ogle, educator, tray,
# Nearest to UNK: atl, cours, conductor, klamath, lawful, acronyms, johnson, iadb,
# Average loss at step 92000: 3.401936
# Average loss at step 94000: 3.253226
# Average loss at step 96000: 3.356893
# Average loss at step 98000: 3.240412
# Average loss at step 100000: 3.357491
# Nearest to other: various, others, escorial, mexica, different, furthest, including, lz,
# Nearest to that: which, however, what, reprise, minyan, auteur, who, where,
# Nearest to system: systems, program, gwynedd, policy, slice, titanium, mmx, ablation,
# Nearest to when: if, although, before, where, while, after, though, during,
# Nearest to was: is, had, became, has, were, been, becomes, sines,
# Nearest to there: they, he, it, now, often, generally, we, she,
# Nearest to state: city, states, ornithologists, browed, platz, inconvenient, territory, violation,
# Nearest to were: are, have, was, had, astrakhan, these, those, including,
# Nearest to new: jamestown, famines, specific, modern, rising, gnostic, mecklenburg, fibre,
# Nearest to these: several, many, some, various, those, all, certain, such,
# Nearest to such: well, known, these, many, defined, certain, opposed, enos,
# Nearest to all: many, every, various, these, some, any, those, several,
# Nearest to often: usually, sometimes, generally, commonly, typically, frequently, now, still,
# Nearest to called: referred, named, used, known, lawn, considered, teased, attributed,
# Nearest to with: between, including, greetings, within, mere, when, specially, supercar,
# Nearest to UNK: yves, moreno, sx, sexist, et, peress, alexius, cours,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, train_labels,tf.reduce_sum(embeds, 1), num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.544525
# Nearest to so: pasta, fundamentals, jaime, linebacker, lingo, dedication, misdemeanor, decidable,
# Nearest to six: prolog, everyday, approving, eui, texans, deutschen, cuisine, sculpted,
# Nearest to an: ural, consumed, ihs, kathryn, ruin, smash, absorbs, taker,
# Nearest to has: adonis, spilled, madame, fiddlers, deaf, renegade, venetia, hypnosis,
# Nearest to no: thalberg, hired, auctions, neuter, incipient, adrienne, phonation, owls,
# Nearest to it: ting, crassus, winchester, steyr, phrygian, inciting, cyclists, stirrup,
# Nearest to this: clouded, skopje, farmer, heracles, halved, tuareg, overturned, aristocrats,
# Nearest to three: transcripts, bulldogs, comrade, restraints, revoked, whitcomb, whey, cadet,
# Nearest to by: mixolydian, fontana, hne, mckee, linkin, waco, millennium, paternity,
# Nearest to from: diadem, supermarket, cse, warr, priceless, monochromatic, ideogram, revisions,
# Nearest to first: multicultural, bernstein, reviewing, mea, terse, benefactors, loo, brest,
# Nearest to the: chong, pesach, synonym, formulaic, imposed, ob, atlases, amano,
# Nearest to about: senseless, nightmares, nbc, tensor, recorders, ceremonial, belushi, basalt,
# Nearest to on: dividend, execute, terminator, genders, lower, stalin, vliw, hindustan,
# Nearest to he: lockout, yr, stem, methodists, mohammed, asf, melanoleuca, primacy,
# Nearest to seven: ampex, padres, imprecise, speedily, hwa, doubts, paperwork, nagasaki,
# Average loss at step 2000: 4.605403
# Average loss at step 4000: 3.934032
# Average loss at step 6000: 3.726737
# Average loss at step 8000: 3.532849
# Average loss at step 10000: 3.471988
# Nearest to so: baton, too, yap, baffling, astigmatism, listener, jaime, keenly,
# Nearest to six: eight, seven, nine, five, four, three, zero, two,
# Nearest to an: synonym, a, another, tractor, the, wodehouse, eduskunta, communions,
# Nearest to has: had, have, was, is, having, eritreans, roadways, compilation,
# Nearest to no: a, uneven, fante, barbary, poodle, any, kilby, unveiling,
# Nearest to it: he, there, this, she, they, which, only, sylia,
# Nearest to this: it, which, the, madrigals, a, patroclus, childbirth, individualistic,
# Nearest to three: six, five, eight, four, seven, zero, two, nine,
# Nearest to by: under, who, macdonald, ensures, awesome, coupon, bins, with,
# Nearest to from: into, around, through, at, during, taraza, on, gains,
# Nearest to first: same, shop, pluralized, most, immigrants, neustria, mother, by,
# Nearest to the: its, his, a, another, their, this, infamy, an,
# Nearest to about: nightmares, leonidas, potassium, strayed, tensor, protozoa, bum, sheik,
# Nearest to on: genders, beatings, in, bristles, from, statesmen, rzburg, episodic,
# Nearest to he: she, it, who, they, tamed, reorganisation, tyre, viridis,
# Nearest to seven: six, nine, eight, five, four, zero, three, two,
# Average loss at step 12000: 3.478149
# Average loss at step 14000: 3.435682
# Average loss at step 16000: 3.435471
# Average loss at step 18000: 3.405906
# Average loss at step 20000: 3.223688
# Nearest to so: deformities, nur, too, garry, fact, larval, airing, worried,
# Nearest to six: seven, four, five, eight, three, zero, nine, two,
# Nearest to an: a, the, this, another, canisters, primetime, tro, byng,
# Nearest to has: had, have, having, is, standardize, annexation, suiko, can,
# Nearest to no: still, any, fante, counsels, gastroenterology, precedent, talk, unveiling,
# Nearest to it: he, she, this, lavoisier, there, anubis, scotus, what,
# Nearest to this: that, it, a, which, the, biomechanics, an, what,
# Nearest to three: four, seven, five, two, six, eight, jalal, zero,
# Nearest to by: macdonald, bins, under, after, shema, rumford, against, when,
# Nearest to from: into, during, through, in, dusty, pfeiffer, while, imre,
# Nearest to first: last, second, same, next, most, jams, halpin, itv,
# Nearest to the: his, its, a, their, any, another, an, this,
# Nearest to about: on, fonts, perversion, aesthetically, dubois, ifor, potassium, metalloid,
# Nearest to on: upon, in, about, czechoslovakian, octave, genders, fangio, logitech,
# Nearest to he: she, it, they, generational, choreographer, funicular, ferruccio, who,
# Nearest to seven: six, eight, five, four, three, zero, nine, two,
# Average loss at step 22000: 3.357408
# Average loss at step 24000: 3.287105
# Average loss at step 26000: 3.258605
# Average loss at step 28000: 3.289017
# Average loss at step 30000: 3.225359
# Nearest to so: too, nur, sup, thrones, berkshire, stating, sometimes, mccarthyism,
# Nearest to six: five, eight, seven, four, nine, three, zero, two,
# Nearest to an: another, tractor, increments, communions, wodehouse, a, the, canisters,
# Nearest to has: had, have, having, is, roadways, was, can, gives,
# Nearest to no: any, little, still, ararat, brigades, melvin, galli, fante,
# Nearest to it: she, he, this, what, there, viridis, still, nursing,
# Nearest to this: it, which, what, the, that, still, decry, some,
# Nearest to three: five, six, four, two, eight, seven, zero, nine,
# Nearest to by: rumford, against, proletarians, folders, shema, satisfiable, when, antoninus,
# Nearest to from: into, through, in, duly, intrusion, during, after, and,
# Nearest to first: last, next, second, same, earliest, later, original, smallholders,
# Nearest to the: its, a, their, this, our, his, cyclical, an,
# Nearest to about: on, how, over, ifor, connectedness, kilobytes, clinically, declarer,
# Nearest to on: upon, across, in, about, beltway, diaries, within, restated,
# Nearest to he: she, it, they, lector, sandstone, scarlet, viridis, transported,
# Nearest to seven: nine, six, eight, five, four, zero, three, one,
# Average loss at step 32000: 3.009605
# Average loss at step 34000: 3.209773
# Average loss at step 36000: 3.191565
# Average loss at step 38000: 3.162170
# Average loss at step 40000: 3.165522
# Nearest to so: nur, stating, says, too, something, sharia, urraca, aircrew,
# Nearest to six: four, eight, five, seven, three, nine, zero, two,
# Nearest to an: another, canisters, communions, consumed, the, a, autoerotic, excise,
# Nearest to has: had, have, having, includes, is, was, suiko, contains,
# Nearest to no: little, any, bayreuth, a, adhemar, an, baum, ararat,
# Nearest to it: he, she, this, mtu, there, anubis, itself, theodor,
# Nearest to this: it, which, the, another, decry, any, she, each,
# Nearest to three: six, four, five, seven, eight, two, nine, zero,
# Nearest to by: when, northside, with, folders, bins, shema, econometric, arg,
# Nearest to from: through, into, during, heracleidae, back, compromising, intrusion, before,
# Nearest to first: last, next, second, same, original, earliest, final, third,
# Nearest to the: its, their, a, this, these, infamy, another, his,
# Nearest to about: over, on, fortieth, lipi, topeka, circuitry, clinically, buyout,
# Nearest to on: upon, across, through, in, within, about, mosander, from,
# Nearest to he: she, it, they, viridis, who, dissociatives, avant, scarlet,
# Nearest to seven: eight, six, four, five, nine, three, zero, two,
# Average loss at step 42000: 3.206666
# Average loss at step 44000: 3.149818
# Average loss at step 46000: 3.141754
# Average loss at step 48000: 3.056207
# Average loss at step 50000: 3.056057
# Nearest to so: sometimes, too, very, yehoshua, worried, sous, kevin, flexible,
# Nearest to six: five, seven, four, eight, three, zero, nine, two,
# Nearest to an: another, canisters, wodehouse, the, flutter, consumed, bm, resentment,
# Nearest to has: had, have, having, is, includes, contains, was, requires,
# Nearest to no: little, nothing, any, another, crying, firsthand, uneven, every,
# Nearest to it: he, she, there, this, burghley, they, locomotion, cel,
# Nearest to this: which, present, another, it, razzie, what, alger, wanderings,
# Nearest to three: seven, five, four, six, eight, zero, nine, two,
# Nearest to by: without, through, toward, folders, under, arg, shema, phrased,
# Nearest to from: through, into, before, during, towards, in, intrusion, culprits,
# Nearest to first: last, next, same, final, earliest, original, second, latter,
# Nearest to the: its, his, a, their, our, an, your, cyclical,
# Nearest to about: around, lipi, kilobytes, jinnah, adage, olds, declarer, fourier,
# Nearest to on: upon, within, around, in, kamov, through, restated, across,
# Nearest to he: she, it, they, who, there, rcc, viridis, mojave,
# Nearest to seven: eight, nine, six, three, five, four, zero, two,
# Average loss at step 52000: 3.093478
# Average loss at step 54000: 3.093015
# Average loss at step 56000: 2.920440
# Average loss at step 58000: 3.026446
# Average loss at step 60000: 3.043526
# Nearest to so: too, concluded, believe, trotskyist, galvani, jud, kevin, fact,
# Nearest to six: five, seven, eight, four, three, zero, nine, two,
# Nearest to an: another, the, ned, canisters, any, primetime, increments, a,
# Nearest to has: had, have, having, is, includes, contains, was, requires,
# Nearest to no: little, any, a, nothing, another, ararat, still, lct,
# Nearest to it: he, she, this, there, bragi, icrc, what, itself,
# Nearest to this: it, which, another, the, raster, what, twigs, every,
# Nearest to three: four, five, six, seven, two, eight, zero, hundred,
# Nearest to by: folders, including, bromwich, under, bins, without, filmography, from,
# Nearest to from: into, through, including, during, towards, intrusion, after, under,
# Nearest to first: last, next, second, earliest, third, final, same, original,
# Nearest to the: a, its, their, his, our, any, an, another,
# Nearest to about: around, bfi, on, bum, clinically, concerning, fullest, oldest,
# Nearest to on: upon, around, across, under, kamov, through, about, in,
# Nearest to he: she, it, they, who, darwin, ferruccio, obsolescence, never,
# Nearest to seven: eight, five, six, nine, three, four, zero, two,
# Average loss at step 62000: 3.017307
# Average loss at step 64000: 2.924280
# Average loss at step 66000: 2.940148
# Average loss at step 68000: 2.946874
# Average loss at step 70000: 3.006361
# Nearest to so: too, larva, underwent, preside, erasing, before, then, verdi,
# Nearest to six: seven, five, three, eight, four, two, zero, wal,
# Nearest to an: another, the, ned, garrick, byng, meany, sympathized, any,
# Nearest to has: had, have, having, requires, includes, contains, is, was,
# Nearest to no: any, nothing, another, baum, little, predicament, beset, woefully,
# Nearest to it: he, she, this, bassoons, only, burghley, they, submit,
# Nearest to this: which, another, a, it, townhouse, razzie, rsdlp, the,
# Nearest to three: five, seven, six, two, four, eight, zero, fifty,
# Nearest to by: through, folders, without, shema, among, phrased, bins, northside,
# Nearest to from: through, beyond, sakharov, intrusion, since, before, towards, during,
# Nearest to first: last, next, second, final, best, third, same, original,
# Nearest to the: a, its, their, his, our, another, any, cyclical,
# Nearest to about: main, concerning, olds, around, clinically, on, lipi, regarding,
# Nearest to on: upon, in, under, around, about, through, behind, avalokitesvara,
# Nearest to he: she, it, they, who, obsolescence, darwin, denounce, polonius,
# Nearest to seven: six, five, three, eight, four, two, zero, nine,
# Average loss at step 72000: 2.944066
# Average loss at step 74000: 2.869424
# Average loss at step 76000: 2.994576
# Average loss at step 78000: 3.004040
# Average loss at step 80000: 2.845595
# Nearest to so: too, sometimes, preside, extremely, underwent, wrinkled, nothing, fact,
# Nearest to six: four, seven, five, eight, three, zero, nine, two,
# Nearest to an: another, canisters, garrick, increments, bm, the, carver, tory,
# Nearest to has: had, have, having, includes, contains, is, requires, consists,
# Nearest to no: little, any, nothing, firsthand, a, kirchenmusik, baum, childe,
# Nearest to it: he, she, there, itself, this, today, what, collusion,
# Nearest to this: which, it, another, decry, what, present, that, controversial,
# Nearest to three: four, five, six, seven, eight, two, zero, nine,
# Nearest to by: without, positing, who, shema, phrased, riel, via, through,
# Nearest to from: through, across, back, intrusion, towards, including, into, krantz,
# Nearest to first: last, next, best, second, same, final, latter, earliest,
# Nearest to the: any, our, their, his, another, a, its, your,
# Nearest to about: concerning, olds, around, cartagena, crosby, kilobytes, fortieth, ifor,
# Nearest to on: upon, in, under, across, through, beltway, concerning, behind,
# Nearest to he: she, it, they, darwin, pinscher, viridis, choreographer, hume,
# Nearest to seven: six, four, five, eight, three, nine, zero, two,
# Average loss at step 82000: 2.938558
# Average loss at step 84000: 2.897215
# Average loss at step 86000: 2.920997
# Average loss at step 88000: 2.947672
# Average loss at step 90000: 2.831302
# Nearest to so: too, underwent, sometimes, extremely, fact, preside, worried, now,
# Nearest to six: four, five, seven, three, eight, nine, zero, two,
# Nearest to an: another, the, any, minimal, canisters, busman, a, garrick,
# Nearest to has: had, have, contains, requires, is, includes, having, provides,
# Nearest to no: little, nothing, any, always, ararat, childe, firsthand, another,
# Nearest to it: he, she, this, there, itself, what, itt, viridis,
# Nearest to this: it, which, another, mathworld, a, what, any, present,
# Nearest to three: five, six, four, seven, eight, two, zero, nine,
# Nearest to by: through, via, shema, coupon, aardvarks, when, positing, toward,
# Nearest to from: through, across, into, since, tab, caracas, in, by,
# Nearest to first: last, next, final, earliest, original, following, second, best,
# Nearest to the: its, their, a, our, any, an, his, whose,
# Nearest to about: over, olds, around, concerning, crosby, tully, minorca, xuan,
# Nearest to on: upon, through, in, across, concerning, kamov, nominative, erm,
# Nearest to he: she, it, they, althusser, eszterh, hume, chadwick, clinton,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Average loss at step 92000: 2.901668
# Average loss at step 94000: 2.884268
# Average loss at step 96000: 2.711305
# Average loss at step 98000: 2.459962
# Average loss at step 100000: 2.707873
# Nearest to so: too, underwent, sometimes, comprehension, jud, fact, wrinkled, margulis,
# Nearest to six: five, seven, four, eight, three, nine, zero, two,
# Nearest to an: another, garrick, canisters, communions, lesotho, autoerotic, increments, busman,
# Nearest to has: had, have, having, contains, requires, includes, is, carries,
# Nearest to no: little, any, nothing, always, firsthand, hum, a, ararat,
# Nearest to it: she, he, there, this, angelico, quite, grips, courageous,
# Nearest to this: which, another, some, it, mathworld, what, intermittent, the,
# Nearest to three: four, five, six, seven, eight, two, zero, nine,
# Nearest to by: phrased, famously, folders, filmography, northside, via, positing, sravaka,
# Nearest to from: across, through, into, via, towards, since, during, internationalist,
# Nearest to first: last, next, second, final, third, earliest, latter, only,
# Nearest to the: a, their, his, its, any, our, another, this,
# Nearest to about: concerning, olds, regarding, around, into, ifor, passionate, ilois,
# Nearest to on: upon, concerning, in, across, through, entitled, kamov, about,
# Nearest to he: she, it, they, who, kerry, there, darwin, viridis,
# Nearest to seven: six, eight, four, five, three, zero, nine, two,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
